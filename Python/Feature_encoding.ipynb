# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_excel('practice_data.xlsx')
df.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
encoder = LabelEncoder()

# %%
df['gender']=encoder.fit_transform(df['gender'])
df.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1       1            Sales            20             High
# 1           2       0        Marketing            22           Medium
# 2           3       1  Human Resources            25             High
# 3           4       1      Engineering            19              Low
# 4           5       0          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
x=df.drop("churned",axis=1)
y=df['churned']

# %%
print("dimension of input features",x.shape)
print("dimension of output feature",y.shape)
# Out:
# dimension of input features (31, 10)
# dimension of output feature (31,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
for i in x.columns:
    if x[i].dtypes=="object":
        x[i]=lb.fit_transform(x[i])

# %%
x.head(3)
# Out:
#    EmployeeID  gender  department  Days Present  Accuracy of Work  \
# 0           1       1           4            20                 0
# 1           2       0           3            22                 2
# 2           3       1           2            25                 0
#
#    Meeting Project Deadlines  Task Completion Rates  \
# 0                          1                     85
# 1                          1                     90
# 2                          0                     80
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# 2                            9                              8
#
#    Sales Revenue Generated
# 0                    51638
# 1                    97797
# 2                    95341

# %%
 x.dtypes
# Out:
# EmployeeID                       int64
# gender                           int32
# department                       int32
# Days Present                     int64
# Accuracy of Work                 int32
# Meeting Project Deadlines        int32
# Task Completion Rates            int64
# Interpersonal Skills Rating      int64
# Decision-Making Skills Rating    int64
# Sales Revenue Generated          int64
# dtype: object

# %%
x = pd.DataFrame(std.fit_transform(x),columns=x.columns)
x
# Out:
#     EmployeeID    gender  department  Days Present  Accuracy of Work  \
# 0    -1.677051  0.849837    1.449138     -0.588120         -1.124298
# 1    -1.565248 -1.176697    0.736070      0.301232          1.199251
# 2    -1.453444  0.849837    0.023002      1.635260         -1.124298
# 3    -1.341641  0.849837   -1.403133     -1.032796          0.037477
# 4    -1.229837 -1.176697   -0.690066      0.745908          1.199251
# 5    -1.118034  0.849837    1.449138     -0.143444         -1.124298
# 6    -1.006231 -1.176697    0.736070      1.190584          0.037477
# 7    -0.894427  0.849837    0.023002     -1.477471          1.199251
# 8    -0.782624  0.849837   -1.403133     -0.588120         -1.124298
# 9    -0.670820 -1.176697   -0.690066      0.301232          1.199251
# 10   -0.559017  0.849837    1.449138      1.635260         -1.124298
# 11   -0.447214 -1.176697    0.736070     -1.032796          0.037477
# 12   -0.335410  0.849837    0.023002      0.745908          1.199251
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1       1            Sales            20             High
# 1           2       0        Marketing            22           Medium
# 2           3       1  Human Resources            25             High
# 3           4       1      Engineering            19              Low
# 4           5       0          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
df['department']=lb.fit_transform(df['department'])
df['Accuracy of Work']=lb.fit_transform(df['Accuracy of Work'])
df['Meeting Project Deadlines']=lb.fit_transform(df['Meeting Project Deadlines'])

# %%
x=df.drop("churned",axis=1)
y=df['churned']

# %%
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#     EmployeeID  gender  department  Days Present  Accuracy of Work  \
# 0     0.000000     1.0        1.00      0.285714               0.0
# 1     0.033333     0.0        0.75      0.571429               1.0
# 2     0.066667     1.0        0.50      1.000000               0.0
# 3     0.100000     1.0        0.00      0.142857               0.5
# 4     0.133333     0.0        0.25      0.714286               1.0
# 5     0.166667     1.0        1.00      0.428571               0.0
# 6     0.200000     0.0        0.75      0.857143               0.5
# 7     0.233333     1.0        0.50      0.000000               1.0
# 8     0.266667     1.0        0.00      0.285714               0.0
# 9     0.300000     0.0        0.25      0.571429               1.0
# 10    0.333333     1.0        1.00      1.000000               0.0
# 11    0.366667     0.0        0.75      0.142857               0.5
# 12    0.400000     1.0        0.50      0.714286               1.0
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
df.head(3)
# Out:
#    EmployeeID  gender  department  Days Present  Accuracy of Work  \
# 0           1       1           4            20                 0
# 1           2       0           3            22                 2
# 2           3       1           2            25                 0
#
#    Meeting Project Deadlines  Task Completion Rates  \
# 0                          1                     85
# 1                          1                     90
# 2                          0                     80
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# 2                            9                              8
#
#    Sales Revenue Generated churned
# 0                    51638      No
# 1                    97797     Yes
# 2                    95341      No

# %%
temp_pca=pca.fit_transform(x)
evr=pca.explained_variance_ratio_
plt.figure(figsize=(10,6))
plt.plot(range(1,len(evr)+1),evr,marker='o')
plt.title("Explained variance ration")
plt.xlabel("Number of Components")
plt.ylabel("Explained Variance ratio")
plt.show()
pca = PCA(n_components=5)
x_pca=pca.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.02,random_state=42)

# %%
print("dimension of training_dataset",x_train.shape,y_train.shape)
print("dimension of testing dataset",x_test.shape,y_test.shape)
# Out:
# dimension of training_dataset (30, 10) (30,)
# dimension of testing dataset (1, 10) (1,)
