# %% [raw]
# # Importing Libraries & Load the File.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('courses_data.csv')
df
# Out:
#      Course_ID       Course_Name  Course _level  Credits
# 0            1           Biology            400        4
# 1            2          Calculus            200        4
# 2            3         Economics            400        5
# 3            4         Economics            300        3
# 4            5           Physics            200        4
# ..         ...               ...            ...      ...
# 195        196        Psychology            100        5
# 196        197           Biology            300        3
# 197        198  Computer Science            300        4
# 198        199         Chemistry            400        5
# 199        200         Economics            100        4
#
# [200 rows x 4 columns]

# %%
# it shows the datatypes of all columns
df.dtypes
# Out:
# Course_ID         int64
# Course_Name      object
# Course _level     int64
# Credits           int64
# dtype: object

# %%
# it shows the stastical summary of data
df.describe()
# Out:
#         Course_ID  Course _level     Credits
# count  200.000000     200.000000  200.000000
# mean   100.500000     263.000000    4.070000
# std     57.879185     113.114875    0.805197
# min      1.000000     100.000000    3.000000
# 25%     50.750000     200.000000    3.000000
# 50%    100.500000     300.000000    4.000000
# 75%    150.250000     400.000000    5.000000
# max    200.000000     400.000000    5.000000

# %%
freq_churned = df['Credits'].value_counts()

plt.figure(figsize = (4,6))
freq_churned.plot(kind = 'bar')
plt.title('Bar Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [raw]
# # stacked or clustered

# %%
cross_tab = pd.crosstab(df['Course_Name'], df['Credits'])

plt.figure(figsize=(4, 6)) 
cross_tab.plot(kind='bar', stacked=False)
plt.title('Course Name by Credits')
plt.xlabel('Course Name')
plt.ylabel('Count')
plt.show()

# %% [raw]
# # Pie Charts

# %%
percentage = df['Credits'].value_counts()

plt.figure(figsize = (4,6))
percentage.plot(kind = 'pie', autopct = '%1.2f%%')
plt.title('Pie Chart')
plt.ylabel('')
plt.show()

# %%
credit_counts = df['Credits'].value_counts()

plt.figure(figsize=(4, 6))
credit_counts.plot(kind='pie', autopct='%1.2f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Pie Charts')
plt.ylabel('')  # Hide the y-axis label
plt.tight_layout()
plt.show()

# %%
# Line Plot
plt.figure(figsize = (4,6))
cross_tab.plot( kind = 'line', marker = 'o')
plt.title('Line plot')
plt.xlabel('Course Name')
plt.ylabel('Credits')
plt.show()

# %%
# Histogram Plot
plt.figure(figsize = (4,6))
df['Credits'].plot(kind = 'hist', bins = 5)
plt.title('Histogram')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

sns.histplot(df['Credits'], bins = 5)
# Out:
# <Axes: xlabel='Credits', ylabel='Count'>
